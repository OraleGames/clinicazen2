# %% [markdown]
# ## todo list
#
# - [ ] Audit dashboard routing
#   - Review AuthContext, dashboard pages, and routing flow to understand how roles should map (ADMIN, THERAPIST, PATIENT, RECEPTIONIST) and current behavior after login.
# - [ ] Implement role-based redirects
#   - Update login/register success handlers and/or dashboard routes so authenticated users land on the correct dashboard for their role, ensuring access control.
# - [ ] Verify dashboards load
#   - Smoke test dashboard pages to ensure required data/hooks are satisfied for each role after redirect changes (at least by reviewing code for missing dependencies).
# - [ ] Run build
#   - Execute project build command to confirm everything compiles after routing updates.
